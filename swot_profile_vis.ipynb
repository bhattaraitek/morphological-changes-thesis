# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib widget

# %%
wl_jan_left = pd.read_csv('C:/Users/bhatt_tk/OneDrive - Stichting Deltares/Desktop/MSc-Thesis/!Proposal/WaterLevel/SWOT_vs_InvD_vs_linear_Interpolation_Jan_left_cl.csv').sort_values(by = 'distance',ascending= True)
wl_jan_right= pd.read_csv('C:/Users/bhatt_tk/OneDrive - Stichting Deltares/Desktop/MSc-Thesis/!Proposal/WaterLevel/SWOT_vs_InvD_vs_linear_Interpolation_Jan_right_cl.csv').sort_values(by = 'distance',ascending= True)
wl_feb_left = pd.read_csv('C:/Users/bhatt_tk/OneDrive - Stichting Deltares/Desktop/MSc-Thesis/!Proposal/WaterLevel/SWOT_vs_InvD_vs_linear_Interpolation_Feb_left_cl.csv').sort_values(by = 'distance',ascending= True)
wl_feb_right = pd.read_csv('C:/Users/bhatt_tk/OneDrive - Stichting Deltares/Desktop/MSc-Thesis/!Proposal/WaterLevel/SWOT_vs_InvD_vs_linear_Interpolation_Feb_right_cl.csv').sort_values(by = 'distance',ascending= True)
wl_mar_left = pd.read_csv('C:/Users/bhatt_tk/OneDrive - Stichting Deltares/Desktop/MSc-Thesis/!Proposal/WaterLevel/SWOT_vs_InvD_vs_linear_Interpolation_Mar_left_cl.csv').sort_values(by = 'distance',ascending= True)
wl_mar_right = pd.read_csv('C:/Users/bhatt_tk/OneDrive - Stichting Deltares/Desktop/MSc-Thesis/!Proposal/WaterLevel/SWOT_vs_InvD_vs_linear_Interpolation_Mar_right_cl.csv').sort_values(by = 'distance',ascending= True)



fig = plt.figure(figsize=(12,5))
# plt.plot(wl_comp['distance']/1000,wl_comp['wl_linear'], label = 'Linear interpolation')
# plt.plot(wl_comp['distance']/1000,wl_comp['wl_invd'], label = 'InvD interpolation')
plt.plot(wl_jan_left['distance']/1000,wl_jan_left['wse']+0.46, label = 'SWOT [Jan.] (left)',c ='red', marker = '*', markersize = 3,markerfacecolor = 'red')
plt.plot(wl_feb_left['distance']/1000,wl_feb_left['wse']+0.46, label = 'SWOT [Feb.] (left)',c ='blue', marker = '*', markersize = 3,markerfacecolor = 'blue')
plt.plot(wl_mar_left['distance']/1000,wl_mar_left['wse']+0.46, label = 'SWOT [Mar.] (left)',c ='green', marker = '*', markersize = 3,markerfacecolor = 'green')
# plt.plot(wl_jan_right['distance']/1000,wl_jan_right['wse']+0.46, label = 'SWOT [Jan.] (right)',c ='yellow', marker = '*', markersize = 3,markerfacecolor = 'red')
# plt.plot(wl_feb_right['distance']/1000,wl_feb_right['wse']+0.46, label = 'SWOT [Feb.] (right)',c ='cyan', marker = '*', markersize = 3,markerfacecolor = 'blue')
# plt.plot(wl_mar_right['distance']/1000,wl_mar_right['wse']+0.46, label = 'SWOT [Mar.] (right)',c ='black', marker = '*', markersize = 3,markerfacecolor = 'green')


plt.xlabel('Distance from Sirajganj station (km)')
plt.ylabel('water level (mPWD)')
plt.title('SWOT Water level profile')
# plt.plot(wl_comp['wseR'], label = 'wse R')
plt.legend()
# wl_comp.iloc[:,1:].corr()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
wl_jan_left = pd.read_csv('C:/Users/bhatt_tk/OneDrive - Stichting Deltares/Desktop/MSc-Thesis/!Proposal/WaterLevel/SWOT_vs_InvD_vs_linear_Interpolation_Jan_left_cl.csv').sort_values(by = 'distance',ascending= True)
wl_jan_right= pd.read_csv('C:/Users/bhatt_tk/OneDrive - Stichting Deltares/Desktop/MSc-Thesis/!Proposal/WaterLevel/SWOT_vs_InvD_vs_linear_Interpolation_Jan_right_cl.csv').sort_values(by = 'distance',ascending= True)
wl_feb_left = pd.read_csv('C:/Users/bhatt_tk/OneDrive - Stichting Deltares/Desktop/MSc-Thesis/!Proposal/WaterLevel/SWOT_vs_InvD_vs_linear_Interpolation_Feb_left_cl.csv').sort_values(by = 'distance',ascending= True)
wl_feb_right = pd.read_csv('C:/Users/bhatt_tk/OneDrive - Stichting Deltares/Desktop/MSc-Thesis/!Proposal/WaterLevel/SWOT_vs_InvD_vs_linear_Interpolation_Feb_right_cl.csv').sort_values(by = 'distance',ascending= True)
wl_mar_left = pd.read_csv('C:/Users/bhatt_tk/OneDrive - Stichting Deltares/Desktop/MSc-Thesis/!Proposal/WaterLevel/SWOT_vs_InvD_vs_linear_Interpolation_Mar_left_cl.csv').sort_values(by = 'distance',ascending= True)
wl_mar_right = pd.read_csv('C:/Users/bhatt_tk/OneDrive - Stichting Deltares/Desktop/MSc-Thesis/!Proposal/WaterLevel/SWOT_vs_InvD_vs_linear_Interpolation_Mar_right_cl.csv').sort_values(by = 'distance',ascending= True)



fig = plt.figure(figsize=(12,5))
# plt.plot(wl_comp['distance']/1000,wl_comp['wl_linear'], label = 'Linear interpolation')
# plt.plot(wl_comp['distance']/1000,wl_comp['wl_invd'], label = 'InvD interpolation')
plt.plot(wl_jan_right['distance']/1000,wl_jan_right['wse']+0.46, label = 'SWOT [Jan.] (right)',c ='red', marker = '*', markersize = 3,markerfacecolor = 'red')
plt.plot(wl_feb_right['distance']/1000,wl_feb_right['wse']+0.46, label = 'SWOT [Feb.] (right)',c ='blue', marker = '*', markersize = 3,markerfacecolor = 'blue')
plt.plot(wl_mar_right['distance']/1000,wl_mar_right['wse']+0.46, label = 'SWOT [Mar.] (right)',c ='green', marker = '*', markersize = 3,markerfacecolor = 'green')

plt.xlabel('Distance from Sirajganj station (km)')
plt.ylabel('water level (mPWD)')
plt.title('SWOT Water level profile')
# plt.plot(wl_comp['wseR'], label = 'wse R')
plt.legend()
# wl_comp.iloc[:,1:].corr()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
